# %% [markdown]
# # INSTRUKCJA INSTALACJI WSL (Windows Subsytem for Linux)
#
# ### Instrukcję opracował: [Krzysztof Kotysz](https://www.krzkot.com)

# %% [markdown]
# ### `bash` jest powłoką systemu operacyjnego opartego na [UNIX](https://upload.wikimedia.org/wikipedia/commons/7/77/Unix_history-simple.svg) - [Linux](https://upload.wikimedia.org/wikipedia/commons/8/8c/Linux_Distribution_Timeline_Dec._2020.svg). Pełni rolę pośrednika między użytkownikiem, a samym systemem. Umożliwia sprawną pracę z plikami i innymi aplikacjami. Występuje wiele powłok systemowych np. `zsh - Z shell`, `tcsh - The TENEX C shell`, `sh - The Bourne shell` i jego ulepszona wersja `bash - The Bourne Again shell ` . Dla Windowsa również występują powłoki: `cmd.exe` oraz `Windows PowerShell`. Aby wywołać powłokę np. bash w Windowsie można użyć narzędzia WSL.

# %% [markdown]
# ## 1. Włączenie funkcji - Podsystem Windows dla systemu Linux

# %% [markdown]
# Żeby włączyć tę funkcję należy wyszukać usługę: Włącz lub wyłącz funkcje systemu Windows.

# %% [markdown]
# ![win-func.png](attachment:win-func.png)

# %% [markdown]
# Następnie trzeba zaznaczyć Podsystem Windows dla systemu Linux

# %% [markdown]
# ![win-wsl_enable.png](attachment:win-wsl_enable.png)

# %% [markdown]
# Po tym, system Windows będzie wymagał ponownego uruchomienia.

# %% [markdown]
# ## 2. Instalacja Linuxa

# %% [markdown]
# Instalacja odbywa się poprzez Windows Store. Należy tam wyszukać pożądaną dystrybucję Linuxa - bardzo przyjazny i polecany jest: <b>Ubuntu</b>. Pozycja nazwana <b>"Ubuntu"</b> zainstaluje najnowszą wersję tej dystrybucji.

# %% [markdown]
# ![win-ubuntu.png](attachment:win-ubuntu.png)

# %% [markdown]
# Po uruchomieniu nastąpi konfiguracja, gdzie trzeba podać nazwę użytkownika i hasło do uwtorzenia nowego konta.

# %% [markdown]
# ## 3. Anaconda
#
# https://repo.anaconda.com/archive/Anaconda3-2021.05-Linux-x86_64.sh
#
# `wget https://repo.anaconda.com/archive/Anaconda3-2021.05-Linux-x86_64.sh`
#
# `bash Anaconda3-2021.05-Linux-x86_64.sh`

# %% [markdown]
# ## 4. Środowisko graficzne - X Server

# %% [markdown]
# Aby wyświetlać uruchamiane programy w formie graficznej (np. wyświetlenie wykresu) trzeba zainstalować dodatkową aplikację na Windowsie - VcXsrv. Musi być uruchomiona przed włączeniem WSL.
#
# https://sourceforge.net/projects/vcxsrv/
#
# Po uruchomieniu należy przeklikać kolejne ekrany i program będzie działał w tle. Następnie należy uruchomić WSL i wpisać komendę:
#
# `export DISPLAY=:0`
